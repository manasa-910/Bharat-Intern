# %% [markdown]
# # Name: Jammalamadaka Manasa

# %% [markdown]
# # Task-1: Stock Prediction

# %% [markdown]
# # Importing libraries

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('C:/Users/MANASA/.jupyter/lab/Stock dataset.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %% [markdown]
# # Checking for null values

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(25,9))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=10)
ax[0].set_ylabel('Price',size=10)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='blue')
ax[1].set_xlabel('Date',size=10)
ax[1].set_ylabel('Price',size=10)
ax[1].legend()

fig.show()

# %% [markdown]
# # Data Preprocessing

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# # Creating LSTM Model

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=40))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 40)                14560
#
#  dense (Dense)               (None, 2)                 82
#
# =================================================================
# Total params: 25242 (98.60 KB)
# Trainable params: 25242 (98.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 10s 118ms/step - loss: 0.0157 - mean_absolute_error: 0.0860 - val_loss: 0.0449 - val_mean_absolute_error: 0.1924
# Epoch 2/100
# 28/28 [==============================] - 2s 71ms/step - loss: 0.0012 - mean_absolute_error: 0.0270 - val_loss: 0.0101 - val_mean_absolute_error: 0.0845
# Epoch 3/100
# 28/28 [==============================] - 4s 140ms/step - loss: 5.3720e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0022 - val_mean_absolute_error: 0.0360
# Epoch 4/100
# 28/28 [==============================] - 2s 75ms/step - loss: 4.5783e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0026 - val_mean_absolute_error: 0.0389
# Epoch 5/100
# 28/28 [==============================] - 2s 88ms/step - loss: 4.5316e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0030 - val_mean_absolute_error: 0.0417
# Epoch 6/100
# 28/28 [==============================] - 2s 77ms/step - loss: 4.6143e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0032 - val_mean_absolute_error: 0.0432
# Epoch 7/100
# 28/28 [==============================] - 2s 63ms/step - loss: 4.3266e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0033 - val_mean_absolute_error: 0.0436
# Epoch 8/100
# 28/28 [==============================] - 2s 71ms/step - loss: 4.0779e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0045 - val_mean_absolute_error: 0.0526
# Epoch 9/100
# 28/28 [==============================] - 2s 74ms/step - loss: 3.9388e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0035 - val_mean_absolute_error: 0.0452
# Epoch 10/100
# 28/28 [==============================] - 3s 90ms/step - loss: 4.0293e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0028 - val_mean_absolute_error: 0.0399
# Epoch 11/100
# 28/28 [==============================] - 3s 99ms/step - loss: 3.8766e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0049 - val_mean_absolute_error: 0.0556
# Epoch 12/100
# 28/28 [==============================] - 3s 106ms/step - loss: 3.6727e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0050 - val_mean_absolute_error: 0.0560
# Epoch 13/100
# 28/28 [==============================] - 3s 95ms/step - loss: 3.9060e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0028 - val_mean_absolute_error: 0.0396
# Epoch 14/100
# 28/28 [==============================] - 3s 91ms/step - loss: 3.7692e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0048 - val_mean_absolute_error: 0.0542
# Epoch 15/100
# 28/28 [==============================] - 3s 97ms/step - loss: 3.5659e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0034 - val_mean_absolute_error: 0.0442
# Epoch 16/100
# 28/28 [==============================] - 3s 101ms/step - loss: 3.5149e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0056 - val_mean_absolute_error: 0.0609
# Epoch 17/100
# 28/28 [==============================] - 3s 94ms/step - loss: 3.4676e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0028 - val_mean_absolute_error: 0.0393
# Epoch 18/100
# 28/28 [==============================] - 2s 81ms/step - loss: 3.4168e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0060 - val_mean_absolute_error: 0.0626
# Epoch 19/100
# 28/28 [==============================] - 2s 86ms/step - loss: 3.4047e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0065 - val_mean_absolute_error: 0.0654
# Epoch 20/100
# 28/28 [==============================] - 3s 99ms/step - loss: 3.6039e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0023 - val_mean_absolute_error: 0.0354
# Epoch 21/100
# 28/28 [==============================] - 3s 103ms/step - loss: 3.4134e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0055 - val_mean_absolute_error: 0.0587
# Epoch 22/100
# 28/28 [==============================] - 3s 115ms/step - loss: 3.1271e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0052 - val_mean_absolute_error: 0.0562
# Epoch 23/100
# 28/28 [==============================] - 2s 79ms/step - loss: 2.9737e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0044 - val_mean_absolute_error: 0.0513
# Epoch 24/100
# 28/28 [==============================] - 2s 85ms/step - loss: 3.1663e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0051 - val_mean_absolute_error: 0.0548
# Epoch 25/100
# 28/28 [==============================] - 2s 70ms/step - loss: 2.9721e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0059 - val_mean_absolute_error: 0.0598
# Epoch 26/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.8089e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0073 - val_mean_absolute_error: 0.0674
# Epoch 27/100
# 28/28 [==============================] - 2s 61ms/step - loss: 3.0531e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0074 - val_mean_absolute_error: 0.0669
# Epoch 28/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.0538e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0048 - val_mean_absolute_error: 0.0522
# Epoch 29/100
# 28/28 [==============================] - 2s 66ms/step - loss: 2.8701e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0034 - val_mean_absolute_error: 0.0419
# Epoch 30/100
# 28/28 [==============================] - 2s 66ms/step - loss: 2.8017e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0057 - val_mean_absolute_error: 0.0576
# Epoch 31/100
# 28/28 [==============================] - 2s 83ms/step - loss: 2.7625e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0037 - val_mean_absolute_error: 0.0444
# Epoch 32/100
# 28/28 [==============================] - 2s 72ms/step - loss: 2.6057e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0049 - val_mean_absolute_error: 0.0534
# Epoch 33/100
# 28/28 [==============================] - 2s 84ms/step - loss: 2.7195e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0046 - val_mean_absolute_error: 0.0502
# Epoch 34/100
# 28/28 [==============================] - 4s 129ms/step - loss: 2.5819e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0041 - val_mean_absolute_error: 0.0475
# Epoch 35/100
# 28/28 [==============================] - 3s 90ms/step - loss: 2.6170e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0043 - val_mean_absolute_error: 0.0506
# Epoch 36/100
# 28/28 [==============================] - 2s 77ms/step - loss: 2.6312e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0041 - val_mean_absolute_error: 0.0472
# Epoch 37/100
# 28/28 [==============================] - 3s 95ms/step - loss: 2.5503e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0064 - val_mean_absolute_error: 0.0631
# Epoch 38/100
# 28/28 [==============================] - 3s 110ms/step - loss: 2.6406e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0043 - val_mean_absolute_error: 0.0474
# Epoch 39/100
# 28/28 [==============================] - 3s 122ms/step - loss: 2.6341e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0057 - val_mean_absolute_error: 0.0559
# Epoch 40/100
# 28/28 [==============================] - 2s 80ms/step - loss: 2.3247e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0041 - val_mean_absolute_error: 0.0470
# Epoch 41/100
# 28/28 [==============================] - 3s 98ms/step - loss: 2.4374e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0053 - val_mean_absolute_error: 0.0546
# Epoch 42/100
# 28/28 [==============================] - 3s 108ms/step - loss: 2.6306e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0061 - val_mean_absolute_error: 0.0613
# Epoch 43/100
# 28/28 [==============================] - 3s 108ms/step - loss: 2.5549e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0046 - val_mean_absolute_error: 0.0521
# Epoch 44/100
# 28/28 [==============================] - 3s 101ms/step - loss: 2.5615e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0028 - val_mean_absolute_error: 0.0384
# Epoch 45/100
# 28/28 [==============================] - 3s 107ms/step - loss: 2.2858e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0035 - val_mean_absolute_error: 0.0421
# Epoch 46/100
# 28/28 [==============================] - 3s 92ms/step - loss: 2.3617e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0046 - val_mean_absolute_error: 0.0533
# Epoch 47/100
# 28/28 [==============================] - 3s 94ms/step - loss: 2.3930e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0045 - val_mean_absolute_error: 0.0510
# Epoch 48/100
# 28/28 [==============================] - 2s 83ms/step - loss: 2.2491e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0054 - val_mean_absolute_error: 0.0557
# Epoch 49/100
# 28/28 [==============================] - 2s 83ms/step - loss: 2.1775e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0045 - val_mean_absolute_error: 0.0500
# Epoch 50/100
# 28/28 [==============================] - 2s 74ms/step - loss: 2.1184e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0033 - val_mean_absolute_error: 0.0412
# Epoch 51/100
# 28/28 [==============================] - 2s 71ms/step - loss: 2.2116e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0073 - val_mean_absolute_error: 0.0703
# Epoch 52/100
# 28/28 [==============================] - 2s 73ms/step - loss: 2.1480e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0036 - val_mean_absolute_error: 0.0447
# Epoch 53/100
# 28/28 [==============================] - 2s 83ms/step - loss: 2.1217e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0041 - val_mean_absolute_error: 0.0507
# Epoch 54/100
# 28/28 [==============================] - 2s 72ms/step - loss: 2.1409e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0046 - val_mean_absolute_error: 0.0520
# Epoch 55/100
# 28/28 [==============================] - 2s 68ms/step - loss: 2.1785e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0029 - val_mean_absolute_error: 0.0396
# Epoch 56/100
# 28/28 [==============================] - 2s 74ms/step - loss: 2.0041e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0026 - val_mean_absolute_error: 0.0374
# Epoch 57/100
# 28/28 [==============================] - 2s 75ms/step - loss: 1.9746e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0035 - val_mean_absolute_error: 0.0440
# Epoch 58/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.9479e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0037 - val_mean_absolute_error: 0.0467
# Epoch 59/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.9371e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0034 - val_mean_absolute_error: 0.0447
# Epoch 60/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.9048e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0034 - val_mean_absolute_error: 0.0443
# Epoch 61/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.1630e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0063 - val_mean_absolute_error: 0.0666
# Epoch 62/100
# 28/28 [==============================] - 3s 95ms/step - loss: 1.9975e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0037 - val_mean_absolute_error: 0.0482
# Epoch 63/100
# 28/28 [==============================] - 2s 82ms/step - loss: 1.9616e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0041 - val_mean_absolute_error: 0.0499
# Epoch 64/100
# 28/28 [==============================] - 2s 76ms/step - loss: 1.9325e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0032 - val_mean_absolute_error: 0.0435
# Epoch 65/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.8965e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0024 - val_mean_absolute_error: 0.0369
# Epoch 66/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.7950e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0028 - val_mean_absolute_error: 0.0401
# Epoch 67/100
# 28/28 [==============================] - 2s 81ms/step - loss: 1.7986e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0015 - val_mean_absolute_error: 0.0282
# Epoch 68/100
# 28/28 [==============================] - 2s 85ms/step - loss: 1.8645e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0026 - val_mean_absolute_error: 0.0395
# Epoch 69/100
# 28/28 [==============================] - 2s 87ms/step - loss: 1.8987e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0043 - val_mean_absolute_error: 0.0533
# Epoch 70/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.7577e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0028 - val_mean_absolute_error: 0.0410
# Epoch 71/100
# 28/28 [==============================] - 2s 73ms/step - loss: 1.6890e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0023 - val_mean_absolute_error: 0.0369
# Epoch 72/100
# 28/28 [==============================] - 2s 73ms/step - loss: 1.7102e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0019 - val_mean_absolute_error: 0.0330
# Epoch 73/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.6143e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0024 - val_mean_absolute_error: 0.0365
# Epoch 74/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.6996e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0023 - val_mean_absolute_error: 0.0365
# Epoch 75/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.6150e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0025 - val_mean_absolute_error: 0.0383
# Epoch 76/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.6085e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0020 - val_mean_absolute_error: 0.0340
# Epoch 77/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.6164e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0018 - val_mean_absolute_error: 0.0315
# Epoch 78/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.5665e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0019 - val_mean_absolute_error: 0.0319
# Epoch 79/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.6861e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0016 - val_mean_absolute_error: 0.0293
# Epoch 80/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.6332e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0023 - val_mean_absolute_error: 0.0374
# Epoch 81/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.5413e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0020 - val_mean_absolute_error: 0.0350
# Epoch 82/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.5825e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0024 - val_mean_absolute_error: 0.0374
# Epoch 83/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.4726e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0017 - val_mean_absolute_error: 0.0309
# Epoch 84/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.5126e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0013 - val_mean_absolute_error: 0.0258
# Epoch 85/100
# 28/28 [==============================] - 2s 76ms/step - loss: 1.6035e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293
# Epoch 86/100
# 28/28 [==============================] - 2s 76ms/step - loss: 1.5319e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0012 - val_mean_absolute_error: 0.0256
# Epoch 87/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.3510e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 88/100
# 28/28 [==============================] - 2s 73ms/step - loss: 1.4304e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0023 - val_mean_absolute_error: 0.0385
# Epoch 89/100
# 28/28 [==============================] - 2s 65ms/step - loss: 1.3837e-04 - mean_absolute_error: 0.0084 - val_loss: 9.7455e-04 - val_mean_absolute_error: 0.0227
# Epoch 90/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.4669e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0021 - val_mean_absolute_error: 0.0362
# Epoch 91/100
# 28/28 [==============================] - 2s 75ms/step - loss: 1.5515e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0015 - val_mean_absolute_error: 0.0285
# Epoch 92/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.3879e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0010 - val_mean_absolute_error: 0.0232
# Epoch 93/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.3707e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0015 - val_mean_absolute_error: 0.0290
# Epoch 94/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.3888e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0016 - val_mean_absolute_error: 0.0303
# Epoch 95/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.2443e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0016 - val_mean_absolute_error: 0.0310
# Epoch 96/100
# 28/28 [==============================] - 2s 71ms/step - loss: 1.1962e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0017 - val_mean_absolute_error: 0.0316
# Epoch 97/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.3296e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0025 - val_mean_absolute_error: 0.0408
# Epoch 98/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.2935e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0025 - val_mean_absolute_error: 0.0397
# Epoch 99/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.2201e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0019 - val_mean_absolute_error: 0.0336
# Epoch 100/100
# 28/28 [==============================] - 2s 83ms/step - loss: 1.2407e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0015 - val_mean_absolute_error: 0.0297

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 3s 21ms/step
# array([[0.40027878, 0.40621975],
#        [0.40104917, 0.4067335 ],
#        [0.3985776 , 0.404007  ],
#        [0.40012687, 0.40564847],
#        [0.40255994, 0.40821558]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1413.0848, 1421.1233],
#        [1414.5131, 1422.0756],
#        [1409.9309, 1417.0223],
#        [1412.8032, 1420.0646],
#        [1417.314 , 1424.8223]], dtype=float32)

# %% [markdown]
# # Data visualisation

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1413.084839      1421.123291
# 2020-05-28  1396.86  1416.73     1414.513062      1422.075562
# 2020-05-29  1416.94  1428.92     1409.930908      1417.022339
# 2020-06-01  1418.39  1431.82     1412.803223      1420.064575
# 2020-06-02  1430.55  1439.22     1417.313965      1424.822266

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(8,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=10)
plt.ylabel('Stock Price',size=10)
plt.title('Actual vs Predicted for open price',size=10)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(8,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=10)
plt.ylabel('Stock Price',size=10)
plt.title('Actual vs Predicted for close price',size=10)
plt.show()

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(8,4))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
